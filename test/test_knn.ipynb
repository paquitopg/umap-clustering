# %%
import sys
sys.path.append("..")

from umap_algo.nn_descent import approx_knn_all_points 
import numpy as np 
import matplotlib.pyplot as plt
# from scipy.spatial.distance import pdist, squareform

# %%
X = np.random.multivariate_normal(np.zeros(2), np.identity(2), size=100)
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
indices, distances = approx_knn_all_points(X, 10)

# %%
i = np.random.randint(100)
plt.scatter(X[:, 0], X[:, 1], alpha=.5)
plt.scatter(X[i, 0], X[i, 1])
plt.scatter(X[indices[i], 0], X[indices[i], 1])
plt.show()
